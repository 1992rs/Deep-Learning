# %%
import numpy as np 
import pandas as pd 
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.7.0'

# %%
df = pd.read_csv('Churn_Modelling.csv') 
X = df.iloc[: , 3:-1].values
y = df.iloc[: , -1]

# %%
print(X) 
X.shape
# Out:
# [[619 'France' 'Female' ... 1 1 101348.88]
#  [608 'Spain' 'Female' ... 0 1 112542.58]
#  [502 'France' 'Female' ... 1 0 113931.57]
#  ...
#  [709 'France' 'Female' ... 0 1 42085.58]
#  [772 'Germany' 'Male' ... 1 0 92888.52]
#  [792 'France' 'Female' ... 1 0 38190.78]]
# (10000, 10)

# %%
print(y)
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
from sklearn.impute import SimpleImputer 
imputer = SimpleImputer(missing_values = np.nan , strategy = 'mean') 
X[: , 3:-1] = imputer.fit_transform(X[: , 3:-1])

# %%
from sklearn.preprocessing import LabelEncoder 
lb = LabelEncoder()
X[:,2] = lb.fit_transform(X[:,2])

# %%
print(X)
# Out:
# [[619 'France' 0 ... 1.0 1.0 101348.88]
#  [608 'Spain' 0 ... 0.0 1.0 112542.58]
#  [502 'France' 0 ... 1.0 0.0 113931.57]
#  ...
#  [709 'France' 0 ... 0.0 1.0 42085.58]
#  [772 'Germany' 1 ... 1.0 0.0 92888.52]
#  [792 'France' 0 ... 1.0 0.0 38190.78]]

# %%
from sklearn.compose import ColumnTransformer 
import numpy as np
from sklearn.preprocessing import OneHotEncoder 
ct = ColumnTransformer(transformers = [('encoder' , OneHotEncoder(), [1])], remainder = 'passthrough') 
X = np.array(ct.fit_transform(X))

# %%
df['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
lb1 = LabelEncoder()
df['Geography_label']=lb1.fit_transform(df['Geography'])
df
# Out:
#       RowNumber  CustomerId  ... Exited  Geography_label
# 0             1    15634602  ...      1                0
# 1             2    15647311  ...      0                2
# 2             3    15619304  ...      1                0
# 3             4    15701354  ...      0                0
# 4             5    15737888  ...      0                2
# ...         ...         ...  ...    ...              ...
# 9995       9996    15606229  ...      0                0
# 9996       9997    15569892  ...      0                0
# 9997       9998    15584532  ...      1                0
# 9998       9999    15682355  ...      1                1
# 9999      10000    15628319  ...      0                0
#
# [10000 rows x 15 columns]

# %%
df['Geography_label'].value_counts()
# Out:
# 0    5014
# 1    2509
# 2    2477
# Name: Geography_label, dtype: int64

# %%
df['Geography'].value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
add_columns = pd.get_dummies(df['Geography']) 
add_columns
# Out:
#       France  Germany  Spain
# 0          1        0      0
# 1          0        0      1
# 2          1        0      0
# 3          1        0      0
# 4          0        0      1
# ...      ...      ...    ...
# 9995       1        0      0
# 9996       1        0      0
# 9997       1        0      0
# 9998       0        1      0
# 9999       1        0      0
#
# [10000 rows x 3 columns]

# %%
df1 =df.join(add_columns)

# %%
df.drop(['Geography'], axis =1 , inplace =True)

# %%
df.drop(['Geography_label'], axis =1 , inplace = True)

# %%
df1
# Out:
#       RowNumber  CustomerId    Surname  ...  France Germany Spain
# 0             1    15634602   Hargrave  ...       1       0     0
# 1             2    15647311       Hill  ...       0       0     1
# 2             3    15619304       Onio  ...       1       0     0
# 3             4    15701354       Boni  ...       1       0     0
# 4             5    15737888   Mitchell  ...       0       0     1
# ...         ...         ...        ...  ...     ...     ...   ...
# 9995       9996    15606229   Obijiaku  ...       1       0     0
# 9996       9997    15569892  Johnstone  ...       1       0     0
# 9997       9998    15584532        Liu  ...       1       0     0
# 9998       9999    15682355  Sabbatini  ...       0       1     0
# 9999      10000    15628319     Walker  ...       1       0     0
#
# [10000 rows x 18 columns]

# %%
columns_names = ['RowNumber' , 'CustomerId' ,'Surname', 'CreditScore' , 'Gender', 'Age', 'Tenure','Balance','NumOfProducts','NumOfProducts','IsActiveMember	','EstimatedSalary','France','Germany','Spain','Exited']

# %%
df1 = df1.reindex(columns = columns_names)

# %%
df1
# Out:
#       RowNumber  CustomerId    Surname  ...  Germany Spain  Exited
# 0             1    15634602   Hargrave  ...        0     0       1
# 1             2    15647311       Hill  ...        0     1       0
# 2             3    15619304       Onio  ...        0     0       1
# 3             4    15701354       Boni  ...        0     0       0
# 4             5    15737888   Mitchell  ...        0     1       0
# ...         ...         ...        ...  ...      ...   ...     ...
# 9995       9996    15606229   Obijiaku  ...        0     0       0
# 9996       9997    15569892  Johnstone  ...        0     0       0
# 9997       9998    15584532        Liu  ...        0     0       1
# 9998       9999    15682355  Sabbatini  ...        1     0       1
# 9999      10000    15628319     Walker  ...        0     0       0
#
# [10000 rows x 16 columns]

# %%
df1['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
lb2 = LabelEncoder()
df1['Gender'] = lb2.fit_transform(df1['Gender'])

# %%
df1
# Out:
#       RowNumber  CustomerId    Surname  ...  Germany  Spain  Exited
# 0             1    15634602   Hargrave  ...        0      0       1
# 1             2    15647311       Hill  ...        0      1       0
# 2             3    15619304       Onio  ...        0      0       1
# 3             4    15701354       Boni  ...        0      0       0
# 4             5    15737888   Mitchell  ...        0      1       0
# ...         ...         ...        ...  ...      ...    ...     ...
# 9995       9996    15606229   Obijiaku  ...        0      0       0
# 9996       9997    15569892  Johnstone  ...        0      0       0
# 9997       9998    15584532        Liu  ...        0      0       1
# 9998       9999    15682355  Sabbatini  ...        1      0       1
# 9999      10000    15628319     Walker  ...        0      0       0
#
# [10000 rows x 16 columns]

# %%
X = df1.iloc[:,3:-1]
y = df1.iloc[:,-1]

# %%
print(X)
# Out:
#       CreditScore  Gender  Age  Tenure  ...  EstimatedSalary  France  Germany  Spain
# 0             619       0   42       2  ...        101348.88       1        0      0
# 1             608       0   41       1  ...        112542.58       0        0      1
# 2             502       0   42       8  ...        113931.57       1        0      0
# 3             699       0   39       1  ...         93826.63       1        0      0
# 4             850       0   43       2  ...         79084.10       0        0      1
# ...           ...     ...  ...     ...  ...              ...     ...      ...    ...
# 9995          771       1   39       5  ...         96270.64       1        0      0
# 9996          516       1   35      10  ...        101699.77       1        0      0
# 9997          709       0   36       7  ...         42085.58       1        0      0
# 9998          772       1   42       3  ...         92888.52       0        1      0
# ...

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(X ,y , test_size =0.2 , random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler 
sc = StandardScaler() 
X_train = sc.fit_transform(X_train) 
X_test = sc.transform(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/extmath.py:986: RuntimeWarning: invalid value encountered in true_divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/extmath.py:991: RuntimeWarning: invalid value encountered in true_divide
#   T = new_sum / new_sample_count
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/extmath.py:1021: RuntimeWarning: invalid value encountered in true_divide
#   new_unnormalized_variance -= correction ** 2 / new_sample_count

# %%
ann = tf.keras.models.Sequential()

# %%
ann.add(tf.keras.layers.Dense( units = 6 , activation = 'relu')) 
ann.add(tf.keras.layers.Dense(units = 6 , activation = 'relu')) 
ann.add(tf.keras.layers.Dense( units = 1 , activation = 'sigmoid'))

# %%
ann.compile(optimizer = 'adam' , loss = 'binary_crossentropy' , metrics = ['accuracy']) 
ann.fit(X_train, y_train , batch_size =32 , epochs = 100)
# Out:
# Epoch 1/100
# 250/250 [==============================] - 2s 2ms/step - loss: nan - accuracy: 0.7960
# Epoch 2/100
# 250/250 [==============================] - 1s 2ms/step - loss: nan - accuracy: 0.7960
# Epoch 3/100
# 250/250 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.7960
# Epoch 4/100
# 250/250 [==============================] - 1s 2ms/step - loss: nan - accuracy: 0.7960
# Epoch 5/100
# 250/250 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.7960
# Epoch 6/100
# 250/250 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.7960
# Epoch 7/100
# 250/250 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.7960
# Epoch 8/100
# 250/250 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.7960
# Epoch 9/100
# 250/250 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.7960
# Epoch 10/100
# ...

# %%
print(ann.predict(sc.transform([[1,0,0,600,1,40,3,60000,2,1,1,50000]])))
# Out:
# [[nan]]
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:446: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"

# %%
y_pred = ann.predict(y_test)
print(np.concatenate((y_pred.reshape(len(y_pred) , 1), y_test.reshape(len(y_test),1))))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-0b212e2d9baa> in <module>()
# ----> 1 y_pred = ann.predict(y_test)
#       2 print(np.concatenate((y_pred.reshape(len(y_pred) , 1), y_test.reshape(len(y_test),1))))
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in autograph_handler(*args, **kwargs)
#    1127           except Exception as e:  # pylint:disable=broad-except
#    1128             if hasattr(e, "ag_error_metadata"):
# ...

# %%
from sklearn.metrics import confusion_matrix , accuracy_score 
cm = confusion_matrix(y_test , y_pred) 
print(cm) 
accuracy_score(y_test , y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-03b79847379b> in <module>()
#       1 from sklearn.metrics import confusion_matrix , accuracy_score
# ----> 2 cm = confusion_matrix(y_test , y_pred)
#       3 print(cm)
#       4 accuracy_score(y_test , y_pred)
#
# NameError: name 'y_test' is not defined
